# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
course1_test = './course_project/course_project_test.csv'
course1_train = './course_project/course_project_train.csv'
course2_test = './web1/data/course_project/test.csv'
course2_train = './web1/data/course_project/train.csv'

# %%
df1_test = pd.read_csv(course1_test)
df1_train = pd.read_csv(course1_train)
df2_test = pd.read_csv(course2_test)
df2_train = pd.read_csv(course2_train)

# %%
(df1_train == df2_train)
# Out:
#       Home Ownership  Annual Income  Years in current job  Tax Liens  \
# 0               True           True                 False       True
# 1               True           True                  True       True
# 2               True           True                  True       True
# 3               True           True                  True       True
# 4               True           True                  True       True
# ...              ...            ...                   ...        ...
# 7495            True           True                  True       True
# 7496            True           True                  True       True
# 7497            True           True                  True       True
# 7498            True          False                 False       True
# 7499            True          False                  True       True
#
#       Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# ...

# %%
df1_test.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0           Rent            NaN              4 years        0.0
# 1           Rent       231838.0               1 year        0.0
# 2  Home Mortgage      1152540.0              3 years        0.0
# 3  Home Mortgage      1220313.0            10+ years        0.0
# 4  Home Mortgage      2340952.0              6 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                      9.0                     12.5             220968.0
# 1                      6.0                     32.7              55946.0
# 2                     10.0                     13.7             204600.0
# 3                     16.0                     17.0             456302.0
# 4                     11.0                     23.6            1207272.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# ...

# %%
df2_test.head()
# Out:
#   Home Ownership  Annual Income Years in current job  Tax Liens  \
# 0           Rent            NaN              4 years        0.0
# 1           Rent       231838.0               1 year        0.0
# 2  Home Mortgage      1152540.0              3 years        0.0
# 3  Home Mortgage      1220313.0            10+ years        0.0
# 4  Home Mortgage      2340952.0              6 years        0.0
#
#    Number of Open Accounts  Years of Credit History  Maximum Open Credit  \
# 0                      9.0                     12.5             220968.0
# 1                      6.0                     32.7              55946.0
# 2                     10.0                     13.7             204600.0
# 3                     16.0                     17.0             456302.0
# 4                     11.0                     23.6            1207272.0
#
#    Number of Credit Problems  Months since last delinquent  Bankruptcies  \
# ...
